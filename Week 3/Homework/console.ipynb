# %% [markdown]
# # URLHAUS

# %%
import urlHaus as u
import importlib
importlib.reload(u)
# Out:
# <module 'urlHaus' from 'c:\\Users\\torfo\\Documents\\SYS-320\\Week 3\\Homework\\urlHaus.py'>

# %%
u.urlHausOpen('../../logs/urlHaus.csv', ['.edu','.gov'])
# Out:
#                     URL: hxxps://yjhgov.work/images/4YhKPqWeoAo2sakyrR5BR43/
#                     Info: https://urlhaus.abuse.ch/url/1992857/
#                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#                     URL: hxxps://yjhgov.work/images/4YhKPqWeoAo2sakyrR5BR43/?i=1
#                     Info: https://urlhaus.abuse.ch/url/1992856/
#                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#                     URL: hxxps://yjhgov.vip/images/yQ8scBrDeQRFH/
#                     Info: https://urlhaus.abuse.ch/url/1990222/
#                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#                     URL: hxxp://govtjobresultbd.xyz/sjjz/UIUhOHsLqjOy9/
#                     Info: https://urlhaus.abuse.ch/url/1976904/
#                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#                     URL: hxxp://govtjobresultbd.xyz/wp-content/9SFD/
# ...
